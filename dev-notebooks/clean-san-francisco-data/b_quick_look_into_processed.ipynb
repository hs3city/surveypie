# %%
import pandas as pd
import seaborn as sns
import os

# %%
processed = os.listdir('processed/')

# %%
processed
# Out:
# ['muni_rate.csv', 'covid_response.csv', 'general_rate.csv']

# %%
f_muni_rates = processed[0]

df = pd.read_csv(os.path.join('processed', f_muni_rates))
df.head()
# Out:
#    BOSdistrict  muni_rate
# 0          5.0        4.0
# 1          5.0        4.0
# 2          9.0        4.0
# 3          5.0        4.0
# 4          5.0        4.0

# %%
sns.kdeplot(data=df, hue='BOSdistrict', x='muni_rate', multiple="fill")
# Out:
# <Axes: xlabel='muni_rate', ylabel='Density'>
